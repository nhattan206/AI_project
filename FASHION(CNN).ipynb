# %% [markdown]
# <a href="https://colab.research.google.com/github/nhattan206/AI_project/blob/main/FASHION(CNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.core.pylabtools import figsize
# Nhận diện chữ số
import numpy as np
import pandas as pd
from keras.datasets import fashion_mnist
from keras.utils import np_utils
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout,Flatten,Conv2D,MaxPooling2D
from tensorflow.keras.optimizers import RMSprop, Adam, SGD
import numpy as np
from keras.backend import conv2d

# %%
(x_train, y_train),(x_test, y_test) = fashion_mnist.load_data()

for i in range(9):
  plt.subplot(330+1+i)
  plt.imshow(x_train[i],cmap = plt.get_cmap('gray'))
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
# Reshape lại dữ liệu
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train/=255 #255 là giá trị lớn nhất của x train và x test
x_test/=255
y_train = np_utils.to_categorical(y_train,10)
y_test = np_utils.to_categorical(y_test,10)

# %%
#Tạo mô hình CNN
model=Sequential()
#Block 1
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer = 'he_uniform',padding='same',input_shape=(28,28,1)))
 #32 sau conv2d là số lần học vs kích thước 3x3 của kernel, input shape là 32x32, 3 kênh màu
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
#Block 2
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer = 'he_uniform',padding='same'))
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
#Block 3
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer = 'he_uniform',padding='same'))
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
#Tạo ANN
model.add(Flatten())
model.add(Dense(256,activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(128,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 128)         73856
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 256)               295168
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 615,786
# Trainable params: 615,786
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Bien Dich
opt=SGD(lr=0.01, momentum=0.9)
model.compile(loss='categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
history=model.fit(x_train,y_train,epochs=100,batch_size=128,validation_data=(x_test,y_test),verbose=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/100
# 469/469 [==============================] - 24s 27ms/step - loss: 0.6184 - accuracy: 0.7783 - val_loss: 0.3753 - val_accuracy: 0.8650
# Epoch 2/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.3335 - accuracy: 0.8774 - val_loss: 0.3146 - val_accuracy: 0.8867
# Epoch 3/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.2789 - accuracy: 0.8982 - val_loss: 0.2984 - val_accuracy: 0.8915
# Epoch 4/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.2461 - accuracy: 0.9093 - val_loss: 0.2848 - val_accuracy: 0.8970
# Epoch 5/100
# 469/469 [==============================] - 13s 29ms/step - loss: 0.2194 - accuracy: 0.9191 - val_loss: 0.2641 - val_accuracy: 0.9061
# Epoch 6/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.1950 - accuracy: 0.9276 - val_loss: 0.2490 - val_accuracy: 0.9098
# Epoch 7/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.1774 - accuracy: 0.9347 - val_loss: 0.2515 - val_accuracy: 0.9121
# Epoch 8/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.1618 - accuracy: 0.9394 - val_loss: 0.2365 - val_accuracy: 0.9144
# Epoch 9/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.1480 - accuracy: 0.9445 - val_loss: 0.2469 - val_accuracy: 0.9115
# Epoch 10/100
# 469/469 [==============================] - 12s 27ms/step - loss: 0.1340 - accuracy: 0.9505 - val_loss: 0.2495 - val_accuracy: 0.9130
# Epoch 11/100
# 469/469 [==============================] - 12s 27ms/step - loss: 0.1177 - accuracy: 0.9564 - val_loss: 0.2633 - val_accuracy: 0.9159
# Epoch 12/100
# 469/469 [==============================] - 12s 27ms/step - loss: 0.1067 - accuracy: 0.9601 - val_loss: 0.2674 - val_accuracy: 0.9142
# Epoch 13/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0959 - accuracy: 0.9646 - val_loss: 0.2674 - val_accuracy: 0.9185
# Epoch 14/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0827 - accuracy: 0.9689 - val_loss: 0.2752 - val_accuracy: 0.9181
# Epoch 15/100
# 469/469 [==============================] - 12s 27ms/step - loss: 0.0755 - accuracy: 0.9710 - val_loss: 0.2889 - val_accuracy: 0.9144
# Epoch 16/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0683 - accuracy: 0.9747 - val_loss: 0.3225 - val_accuracy: 0.9137
# Epoch 17/100
# 469/469 [==============================] - 12s 27ms/step - loss: 0.0603 - accuracy: 0.9770 - val_loss: 0.3327 - val_accuracy: 0.9190
# Epoch 18/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0540 - accuracy: 0.9793 - val_loss: 0.3551 - val_accuracy: 0.9195
# Epoch 19/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0505 - accuracy: 0.9812 - val_loss: 0.3404 - val_accuracy: 0.9133
# Epoch 20/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0442 - accuracy: 0.9836 - val_loss: 0.3669 - val_accuracy: 0.9184
# Epoch 21/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0423 - accuracy: 0.9842 - val_loss: 0.3491 - val_accuracy: 0.9178
# Epoch 22/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0393 - accuracy: 0.9850 - val_loss: 0.3928 - val_accuracy: 0.9163
# Epoch 23/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0340 - accuracy: 0.9876 - val_loss: 0.3800 - val_accuracy: 0.9199
# Epoch 24/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0305 - accuracy: 0.9885 - val_loss: 0.4281 - val_accuracy: 0.9163
# Epoch 25/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0300 - accuracy: 0.9893 - val_loss: 0.4395 - val_accuracy: 0.9125
# Epoch 26/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0286 - accuracy: 0.9898 - val_loss: 0.4465 - val_accuracy: 0.9184
# Epoch 27/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0272 - accuracy: 0.9902 - val_loss: 0.4385 - val_accuracy: 0.9150
# Epoch 28/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0263 - accuracy: 0.9899 - val_loss: 0.4310 - val_accuracy: 0.9179
# Epoch 29/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0227 - accuracy: 0.9918 - val_loss: 0.4651 - val_accuracy: 0.9186
# Epoch 30/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0266 - accuracy: 0.9908 - val_loss: 0.4673 - val_accuracy: 0.9130
# Epoch 31/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0255 - accuracy: 0.9912 - val_loss: 0.4420 - val_accuracy: 0.9126
# Epoch 32/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0169 - accuracy: 0.9941 - val_loss: 0.4959 - val_accuracy: 0.9176
# Epoch 33/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0128 - accuracy: 0.9957 - val_loss: 0.4985 - val_accuracy: 0.9176
# Epoch 34/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0176 - accuracy: 0.9937 - val_loss: 0.5124 - val_accuracy: 0.9150
# Epoch 35/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0206 - accuracy: 0.9927 - val_loss: 0.4940 - val_accuracy: 0.9190
# Epoch 36/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0155 - accuracy: 0.9947 - val_loss: 0.4834 - val_accuracy: 0.9191
# Epoch 37/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0135 - accuracy: 0.9954 - val_loss: 0.5283 - val_accuracy: 0.9181
# Epoch 38/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0184 - accuracy: 0.9934 - val_loss: 0.5051 - val_accuracy: 0.9187
# Epoch 39/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0138 - accuracy: 0.9949 - val_loss: 0.5127 - val_accuracy: 0.9145
# Epoch 40/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0151 - accuracy: 0.9947 - val_loss: 0.5244 - val_accuracy: 0.9174
# Epoch 41/100
# 469/469 [==============================] - 12s 27ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.5657 - val_accuracy: 0.9164
# Epoch 42/100
# 469/469 [==============================] - 12s 27ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.5505 - val_accuracy: 0.9191
# Epoch 43/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.5128 - val_accuracy: 0.9228
# Epoch 44/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.5814 - val_accuracy: 0.9222
# Epoch 45/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0110 - accuracy: 0.9963 - val_loss: 0.5465 - val_accuracy: 0.9208
# Epoch 46/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.5783 - val_accuracy: 0.9206
# Epoch 47/100
# 469/469 [==============================] - 13s 28ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.6014 - val_accuracy: 0.9231
# Epoch 48/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.6107 - val_accuracy: 0.9200
# Epoch 49/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.6086 - val_accuracy: 0.9182
# Epoch 50/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.5654 - val_accuracy: 0.9140
# Epoch 51/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0084 - accuracy: 0.9972 - val_loss: 0.6113 - val_accuracy: 0.9146
# Epoch 52/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0110 - accuracy: 0.9964 - val_loss: 0.5552 - val_accuracy: 0.9188
# Epoch 53/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0109 - accuracy: 0.9965 - val_loss: 0.6284 - val_accuracy: 0.9157
# Epoch 54/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.5406 - val_accuracy: 0.9162
# Epoch 55/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.5732 - val_accuracy: 0.9193
# Epoch 56/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0092 - accuracy: 0.9969 - val_loss: 0.5591 - val_accuracy: 0.9195
# Epoch 57/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.5962 - val_accuracy: 0.9209
# Epoch 58/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.6532 - val_accuracy: 0.9237
# Epoch 59/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.6741 - val_accuracy: 0.9171
# Epoch 60/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.6841 - val_accuracy: 0.9187
# Epoch 61/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.6673 - val_accuracy: 0.9184
# Epoch 62/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.7215 - val_accuracy: 0.9136
# Epoch 63/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.6493 - val_accuracy: 0.9193
# Epoch 64/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0025 - accuracy: 0.9994 - val_loss: 0.6681 - val_accuracy: 0.9203
# Epoch 65/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.7293 - val_accuracy: 0.9231
# Epoch 66/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.7552 - val_accuracy: 0.9188
# Epoch 67/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.6347 - val_accuracy: 0.9170
# Epoch 68/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.6516 - val_accuracy: 0.9209
# Epoch 69/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.7013 - val_accuracy: 0.9205
# Epoch 70/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.6607 - val_accuracy: 0.9200
# Epoch 71/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.6532 - val_accuracy: 0.9202
# Epoch 72/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.7928 - val_accuracy: 0.9156
# Epoch 73/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0106 - accuracy: 0.9964 - val_loss: 0.6602 - val_accuracy: 0.9127
# Epoch 74/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.6306 - val_accuracy: 0.9202
# Epoch 75/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0017 - accuracy: 0.9996 - val_loss: 0.7182 - val_accuracy: 0.9221
# Epoch 76/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 0.6795 - val_accuracy: 0.9189
# Epoch 77/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0110 - accuracy: 0.9964 - val_loss: 0.6554 - val_accuracy: 0.9150
# Epoch 78/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.7078 - val_accuracy: 0.9205
# Epoch 79/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.6534 - val_accuracy: 0.9120
# Epoch 80/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0106 - accuracy: 0.9967 - val_loss: 0.6596 - val_accuracy: 0.9186
# Epoch 81/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.6842 - val_accuracy: 0.9231
# Epoch 82/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.6181 - val_accuracy: 0.9169
# Epoch 83/100
# 469/469 [==============================] - 12s 26ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.6287 - val_accuracy: 0.9206
# Epoch 84/100
# 469/469 [==============================] - 13s 27ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.7086 - val_accuracy: 0.9235
# Epoch 85/100
# 469/469 [==============================] - 13s 27ms/step - loss: 1.1192e-04 - accuracy: 1.0000 - val_loss: 0.7364 - val_accuracy: 0.9237
# Epoch 86/100
# 469/469 [==============================] - 12s 26ms/step - loss: 2.6773e-05 - accuracy: 1.0000 - val_loss: 0.7422 - val_accuracy: 0.9235
# Epoch 87/100
# 469/469 [==============================] - 12s 26ms/step - loss: 1.7519e-05 - accuracy: 1.0000 - val_loss: 0.7500 - val_accuracy: 0.9233
# Epoch 88/100
# 469/469 [==============================] - 13s 27ms/step - loss: 1.4384e-05 - accuracy: 1.0000 - val_loss: 0.7565 - val_accuracy: 0.9233
# Epoch 89/100
# 469/469 [==============================] - 12s 26ms/step - loss: 1.2466e-05 - accuracy: 1.0000 - val_loss: 0.7622 - val_accuracy: 0.9233
# Epoch 90/100
# 469/469 [==============================] - 13s 27ms/step - loss: 1.1063e-05 - accuracy: 1.0000 - val_loss: 0.7670 - val_accuracy: 0.9233
# Epoch 91/100
# 469/469 [==============================] - 13s 28ms/step - loss: 9.9753e-06 - accuracy: 1.0000 - val_loss: 0.7712 - val_accuracy: 0.9231
# Epoch 92/100
# 469/469 [==============================] - 13s 27ms/step - loss: 9.1119e-06 - accuracy: 1.0000 - val_loss: 0.7754 - val_accuracy: 0.9232
# Epoch 93/100
# 469/469 [==============================] - 13s 28ms/step - loss: 8.3923e-06 - accuracy: 1.0000 - val_loss: 0.7791 - val_accuracy: 0.9232
# Epoch 94/100
# 469/469 [==============================] - 13s 27ms/step - loss: 7.7831e-06 - accuracy: 1.0000 - val_loss: 0.7826 - val_accuracy: 0.9232
# Epoch 95/100
# 469/469 [==============================] - 12s 26ms/step - loss: 7.2644e-06 - accuracy: 1.0000 - val_loss: 0.7858 - val_accuracy: 0.9231
# Epoch 96/100
# 469/469 [==============================] - 12s 26ms/step - loss: 6.8101e-06 - accuracy: 1.0000 - val_loss: 0.7889 - val_accuracy: 0.9232
# Epoch 97/100
# 469/469 [==============================] - 13s 27ms/step - loss: 6.4138e-06 - accuracy: 1.0000 - val_loss: 0.7918 - val_accuracy: 0.9233
# Epoch 98/100
# 469/469 [==============================] - 13s 28ms/step - loss: 6.0601e-06 - accuracy: 1.0000 - val_loss: 0.7945 - val_accuracy: 0.9234
# Epoch 99/100
# 469/469 [==============================] - 13s 27ms/step - loss: 5.7470e-06 - accuracy: 1.0000 - val_loss: 0.7971 - val_accuracy: 0.9233
# Epoch 100/100
# 469/469 [==============================] - 12s 26ms/step - loss: 5.4647e-06 - accuracy: 1.0000 - val_loss: 0.7996 - val_accuracy: 0.9233

# %%
#Ve do thi
pd.DataFrame(history.history).plot(figsize= (8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc = 'upper left')
plt.show()
